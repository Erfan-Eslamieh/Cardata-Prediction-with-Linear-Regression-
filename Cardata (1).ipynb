# %% [markdown]
# <div style="background-color: #CBC3E3; padding: 20px; text-align: center;">
#     <span style="font-size: 48px; color: #000000; font-family: cursive;">Hello everyone!</span>
# </div>

# %% [markdown]
# <h1 style="text-align:center; font-size: 30px;">
#     <span style="color:black;">Used Car Price Prediction with Linear Regression🚗📈
#    </span>
# </h1>

# %% [markdown]
# <div style="text-align: center;"><img src= "https://carbaazar.com/assets/images/sell-vehicule.png" style="width:100%; max-width:1200px;"></div>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">A Brief Explenation 💻</p>
#
# <div style = 'border : 3px solid none; background-color:#f2f2f2; padding:10px'>
#
# Car Price Analysis: Understanding the Used Car Market 🚗📊
# The used car market is a dynamic industry influenced by factors such as depreciation, fuel type, ownership history, and market demand. The "Car Price Dataset" provides valuable insights into the pricing trends of pre-owned vehicles based on key attributes like selling price, present market value, driven kilometers, fuel type, transmission type, and seller category.
#
# Objective of the Study
# This study aims to analyze used car prices using data visualization techniques to identify trends, correlations, and key factors affecting resale value. By leveraging statistical analysis and machine learning models, we can explore how different attributes impact the final selling price of a vehicle.
#
# Key Steps in the Study:
#
# ✅ Data Cleaning and Preprocessing:
#
# Handling missing values and ensuring consistency in pricing metrics.
#
# Converting categorical data (e.g., fuel type, transmission type) into numerical formats for better analysis.
#
# ✅ Exploratory Data Analysis (EDA):
#
# Visualizing distributions of car prices based on year, fuel type, and transmission type.
#
# Analyzing the relationship between driven kilometers and resale value.
#
# ✅ Pattern Identification & Market Trends:
#
# Evaluating how fuel type (Petrol, Diesel, CNG) affects car pricing.
#
# Examining the influence of ownership history (first-owner vs. multiple owners) on depreciation.
#
# ✅ Regression Models & Prediction:
#
# Two Linear Regression models were applied, one with normalized data to improve accuracy.
#
# The final prediction (y_pred) was obtained and visualized.
#
# Since we aimed to predict specific data points, a final prediction of car prices was made for vehicles with given specifications.
#
# By applying descriptive statistics, data visualization techniques, and regression analysis, this study enhances our understanding of the factors shaping the second-hand car market. These insights can help buyers, sellers, and industry analysts make informed decisions when purchasing or selling used vehicles. 🚘📈
#
# </div>

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Description of all columns in our dataset</p>
#
#
# <div style = 'border : 3px solid none; background-color:#f2f2f2; padding:10px'>
#
# ## **Column Descriptions:**
#
#  **Car_Name:**
# *  The name or model of the car as listed in the dataset.
#
#  **Year:**
#  * The manufacturing year of the car, indicating how old the vehicle is.
#
#  **Selling_Price:**
#  * The final selling price of the car (in lakhs of Indian Rupees), representing the amount the vehicle was sold for in the market.
#
#  **Present_Price:**
#  * The original showroom price of the car when it was brand new, helping to compare depreciation over time.
#
#  **Kms_Driven:**
#  * The total distance the car has been driven, measured in kilometers, which affects its valuation and wear-and-tear condition.
#
#  **Fuel_Type:**
#  * The type of fuel the car runs on, categorized as Petrol, Diesel, or CNG, influencing fuel efficiency and running costs.
#
#  **Seller_Type:**
#  * Specifies whether the car is being sold by an individual or a dealer, impacting trust and pricing expectations.
#
#  **Transmission:**
#  * Defines the type of gear system in the car, either Manual or Automatic, affecting driving experience and maintenance costs.
#
#  **Owner:**
#  * Indicates the number of previous owners the car has had, with values such as 0 for first owner, 1 for second owner, and so on, which can impact resale  value.

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Input data for price prediction</p>
#
# <div style = 'border : 3px solid none; background-color:#f2f2f2; padding:10px'>
#
#  **Cost of new Car:**
#
#
# * **Present Prise = 11.23**
#
#
# * **KMS Driven = 42/000**
#
#
# * **Fuel Type = Petrol**
#
#
# * **Seller Type = Dealer**
#
#
# * **Transmision = Manual**
#
#
# * **Owner = 1**
#
#
# * **Age = 10**
#
# * **Price?**
#
# </div>

# %% [markdown]
# <a id="0"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table of Contents 💻</p>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#f2f2f2
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px; color: #000000'>
#
# * **[1. A Brief Explenation 💻](#1)**
#
#
# * **[2. Description of all columns in our dataset](#2)**
#
#
# * **[3. Input data for price prediction](#3)**
#   - we hve some input data for Prediction Price of given informations'car
#
#
# * **[4. Import Libraries ](#4)**
#
#   - Libraries that we need in this project
#
#
# * **[5. call Dataset ](#5)**
#
#    - Calling the dataset (ٍCar dataset)
#
#
# * **[6. Exploratory Data Analysis (EDA) ](#6)**
#
#    - Get rid of missing values
#    - Get rid of Noises
#    - Sort all data and sort columns
#
#
# * **[7. Visulization of Data](#7)**
#    - Ploting & visualization
#
# * **[8. Replace Categorical Values](#8)**
#
#   - call numerical Columns
#   - see the variables' name of each columns
#   - replace Variable'names of "Fuel_Type", "Seller_Type", "Transmission" with numbers
#
#
# * **[9. Create Models](#9)**
#
#   - Model 1: Linear Regression
#   - Model 2: Linear Regression
#   - Prediction
#   - predict our new Car Price base on Model Prediction

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Import Libraries</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn import preprocessing
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Call Dataset</p>

# %%
data = pd.read_csv("cardata.csv")
df = pd.DataFrame(data)
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Exploratory Data Analysis (EDA)</p>

# %% [markdown]
# <div style = 'border : 5px solid none; background-color:#f2f2f2; padding:10px'>
#
#
# **Deleting the column "Car name" because it is useless for our Data**
#
#
# </div>

# %%
df1 = df.drop(['Car_Name'], axis=1)
df1
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df1.shape
# Out:
# (301, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    object
#  5   Seller_Type    301 non-null    object
#  6   Transmission   301 non-null    object
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 18.9+ KB

# %%
df1.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df1.isna().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
np.max(df1["Year"])
# Out:
# 2018

# %%
df1["Age"] = 2019 - df1["Year"]
df1.drop("Year", axis = 1 , inplace = True)

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0    5
# 1         Manual      0    6
# 2         Manual      0    2
# 3         Manual      0    8
# ...

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Visulization of Data</p>

# %%
plt.figure(figsize = (35,25))
s = df1['Fuel_Type'].value_counts()
s = df1['Fuel_Type'].value_counts().rename_axis('Fuel_Type').rename('count') 
sns.barplot(x=s.index, y=s.values, order=s.index)
plt.xticks(rotation = 90, fontsize = 30)
plt.yticks( fontsize = 30)
plt.xlabel("Fuel Type", fontsize = 45, labelpad = 30)
plt.ylabel("Count", fontsize = 45)
plt.show()

# %%
plt.figure(figsize = (35,25))
s = df1['Seller_Type'].value_counts()
s = df1['Seller_Type'].value_counts().rename_axis('Seller_Type').rename('count') 
sns.barplot(x=s.index, y=s.values, order=s.index)
plt.xticks(rotation = 90, fontsize = 30)
plt.yticks( fontsize = 30)
plt.xlabel("Seller Type", fontsize = 45, labelpad = 30)
plt.ylabel("Count", fontsize = 45,  labelpad = 30)
plt.show()

# %%
plt.figure(figsize = (35,25))
s = df1['Transmission'].value_counts()
s = df1['Transmission'].value_counts().rename_axis('Transmission').rename('count') 
sns.barplot(x=s.index, y=s.values, order=s.index)
plt.xticks(rotation = 90, fontsize = 30)
plt.yticks( fontsize = 30)
plt.xlabel("Transmission", fontsize = 45, labelpad = 30)
plt.ylabel("Count", fontsize = 45,  labelpad = 30)
plt.show()

# %%
plt.figure(figsize = (35,25))
s = df1['Owner'].value_counts()
s = df1['Owner'].value_counts().rename_axis('Owner').rename('count') 
sns.barplot(x=s.index, y=s.values, order=s.index)
plt.xticks(rotation = 90, fontsize = 30)
plt.yticks( fontsize = 30)
plt.xlabel("Owner", fontsize = 45, labelpad = 30)
plt.ylabel("Count", fontsize = 45,  labelpad = 30)
plt.show()

# %%
plt.figure(figsize=(35, 25))
sns.boxplot(data=df1, x='Selling_Price')  
plt.xticks(rotation=90, fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel("Selling Price", fontsize=45, labelpad=30)
plt.show()

# %%
plt.figure(figsize=(35, 25))
sns.boxplot(data=df1, x='Present_Price')  
plt.xticks(rotation=90, fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel("Present Price", fontsize=45, labelpad=30)
plt.show()

# %%
plt.figure(figsize=(35, 25))
sns.boxplot(data=df1, x='Kms_Driven')  
plt.xticks(rotation=90, fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel("Kms Driven", fontsize=45, labelpad=30)
plt.show()

# %%
plt.figure(figsize=(35, 25))
sns.boxplot(data=df1, x='Age')  
plt.xticks(rotation=90, fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel("Age", fontsize=45, labelpad=30)
plt.show()

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Replace Categorical Values</p>

# %% [markdown]
# #### with unique we can see the variables'name of each columns

# %%
cols = ["Fuel_Type", "Seller_Type", "Transmission", "Owner"]
for col in cols:
    print(f"Unique values in {col}: {pd.unique(data[col])}")
# Out:
# Unique values in Fuel_Type: ['Petrol' 'Diesel' 'CNG']
# Unique values in Seller_Type: ['Dealer' 'Individual']
# Unique values in Transmission: ['Manual' 'Automatic']
# Unique values in Owner: [0 1 3]

# %% [markdown]
# #### Now, we want to rename each variable and replace names with numbers. We also want to raise them to a power, but we cannot use 0 or 1

# %%
df1["Fuel_Type"].replace({"Petrol":2, "Diesel":3, "CNG":4}, inplace = True)
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %%
df1["Seller_Type"].replace({"Dealer":2, "Individual":3}, inplace = True)
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %%
df1["Transmission"].replace({"Manual":2, "Automatic":3}, inplace = True)
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %% [markdown]
#  <div style = 'border : 10px solid none; background-color:#f2f2f2; padding:10px;font-size:20'>
#
# ### **We have columns that are numerical**
# </div>

# %%
df1.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Selling_Price       1.000000       0.878983    0.029187   0.509467
# Present_Price       0.878983       1.000000    0.203647   0.440415
# Kms_Driven          0.029187       0.203647    1.000000   0.166801
# Fuel_Type           0.509467       0.440415    0.166801   1.000000
# Seller_Type        -0.550724      -0.512030   -0.101419  -0.352415
# Transmission        0.367128       0.348715    0.162510   0.080466
# Owner              -0.088344       0.008057    0.089216  -0.055705
# Age                -0.236141       0.047584    0.524342  -0.053643
#
#                Seller_Type  Transmission     Owner       Age
# Selling_Price    -0.550724      0.367128 -0.088344 -0.236141
# Present_Price    -0.512030      0.348715  0.008057  0.047584
# Kms_Driven       -0.101419      0.162510  0.089216  0.524342
# Fuel_Type        -0.352415      0.080466 -0.055705 -0.053643
# ...

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:#CBC3E3 ;margin:0;color:#000000 ;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Create Models</p>

# %% [markdown]
# ## Model 1
#
# #### we drop "Selling_Price" in order to seperate our target from another columns

# %%
x = df1.drop("Selling_Price", axis = 1)
y = df1["Selling_Price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)
print("x train: ", x_train.shape)
print("x test: ", x_test.shape)
print("y train: ", y_train.shape)
print("y test: ", y_test.shape)
# Out:
# x train:  (240, 7)
# x test:  (61, 7)
# y train:  (240,)
# y test:  (61,)

# %%
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(x_test)

# %%
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: " ,metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  1.1530045916158924
# Mean Squared Error:  3.2876460857158376
# Root Mean Squared Error:  1.8131867211392867
# R2 Score:  0.8484549412090379

# %%
k_fold = KFold(10)
print(cross_val_score(model1, x, y.ravel(), cv = k_fold, n_jobs = 1))
# Out:
# [ 6.63522141e-01  8.80842763e-01  7.23708463e-01  8.63126108e-01
#  -4.36488306e+01 -1.07944231e+03 -3.50129071e-01  7.84378582e-01
#   8.27975783e-01  8.74089252e-01]

# %%
len(df1)/10
# Out:
# 30.1

# %%
df2 = df1[df1.index < 120]  
df3 = df1[df1.index > 210]  
df4 = pd.concat([df2, df3])
df4.reset_index(drop=True, inplace=True)
df4
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 205           9.50          11.60       33988          3            2
# 206           4.00           5.90       60000          2            2
# 207           3.35          11.00       87934          2            2
# 208          11.50          12.50        9000          3            2
# 209           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %% [markdown]
# ## Model 2

# %%
x2 = df4.drop("Selling_Price", axis = 1)
y2 = df4["Selling_Price"]

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size = 0.2, random_state = 1)

# %%
model2 = LinearRegression()
model2.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = model2.predict(x_test2)

# %%
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test2, y_pred2))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test2, y_pred2))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 Score: " ,metrics.r2_score(y_test2, y_pred2))
# Out:
# Mean Absolute Error:  1.2344068697754254
# Mean Squared Error:  2.6238982580770434
# Root Mean Squared Error:  1.6198451339794935
# R2 Score:  0.8793462370195001

# %% [markdown]
# #### Now we know R2 score 2 = 0.87 > R2 score 1 = 0.84

# %%
print("Model Intercept = ", model2.intercept_)
print("Model coefs = ", model2.coef_)
# Out:
# Model Intercept =  -1.6962350442029566
# Model coefs =  [ 4.42320455e-01 -2.66901271e-05  2.25919515e+00 -1.26225774e+00
#   2.10515821e+00 -1.13003710e+00 -4.62552614e-01]

# %% [markdown]
# ### Our Main Model

# %%
x = pd.DataFrame(df1 , columns = [ "Present_Price","Kms_Driven","Fuel_Type","Seller_Type","Transmission","Owner","Age"])
y = df1.Selling_Price.values.reshape(-1,1)
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  Age
# 0               2      0    5
# 1               2      0    6
# 2               2      0    2
# ...

# %%
x
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          3            2             2      0
# 297           5.90       60000          2            2             2      0
# 298          11.00       87934          2            2             2      0
# 299          12.50        9000          3            2             2      0
# 300           5.90        5464          2            2             2      0
#
#      Age
# 0      5
# 1      6
# 2      2
# 3      8
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: " ,metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  1.0000326012144771
# Mean Squared Error:  2.1885564456572246
# Root Mean Squared Error:  1.4793770464818037
# R2 Score:  0.913418172122469

# %%
r2 = 0.9134181721224691

column = x.columns[0]
New_col_Name = column + "_2"
New_col_Val = x[column] ** 2
x[New_col_Name] = New_col_Val

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

r2_new = metrics.r2_score(y_test, y_pred)

if r2_new > r2:
    print("مدل بهبود پیدا کرد ✅")
    r2 = r2_new
else:
    print("مدل بهبود پیدا نکرد ❌")
    x.drop([New_col_Name], axis=1, inplace=True)

print("R2 score:", r2)
# Out:
# مدل بهبود پیدا کرد ✅
# R2 score: 0.9198798658487877

# %%
x
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          3            2             2      0
# 297           5.90       60000          2            2             2      0
# 298          11.00       87934          2            2             2      0
# 299          12.50        9000          3            2             2      0
# 300           5.90        5464          2            2             2      0
#
#      Age  Present_Price_2
# 0      5          31.2481
# ...

# %%
x['Kms_Driven2'] = x['Kms_Driven'] ** 2
x['Present_Price2'] = x['Present_Price'] ** 2
x['Fuel_Type2'] = x['Fuel_Type'] ** 2
x['Owner2'] = x['Owner'] ** 2


# محاسبات اصلی
x['pres_Kms']     = x['Present_Price']  * x['Kms_Driven']
x['pres_Kms2']    = x['Present_Price']  * x['Kms_Driven']
x['pres_Fuel']    = x['Present_Price']  * x['Fuel_Type']
x['pres_Fuel2']   = x['Present_Price']  * x['Fuel_Type2']
x['pres2_Kms']    = x['Present_Price2'] * x['Kms_Driven']
x['pres2_Kms2']   = x['Present_Price2'] * x['Kms_Driven2']
x['pres2_Fuel']   = x['Present_Price2'] * x['Fuel_Type']
x['pres2_Fuel2']  = x['Present_Price2'] * x['Fuel_Type2']

# %%
df2 = x
df2
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 296          11.60       33988          3            2             2      0
# 297           5.90       60000          2            2             2      0
# 298          11.00       87934          2            2             2      0
# 299          12.50        9000          3            2             2      0
# 300           5.90        5464          2            2             2      0
#
# ...

# %%
df3 = df2.loc[:,["pres_Kms","pres_Kms2", "pres_Fuel", "pres_Fuel2", "pres2_Kms", "pres2_Kms2", "pres2_Fuel", "pres2_Fuel2", "Owner2", "Owner", "Fuel_Type2", "Kms_Driven2", "Present_Price2", "Present_Price", "Kms_Driven", "Fuel_Type", "Seller_Type", "Transmission", "Age"]]

# %%
df3
# Out:
#      pres_Kms  pres_Kms2  pres_Fuel  pres_Fuel2     pres2_Kms    pres2_Kms2  \
# 0    150930.0   150930.0      11.18       22.36  8.436987e+05  2.277986e+10
# 1    410220.0   410220.0      28.62       85.86  3.913499e+06  1.682804e+11
# 2     67965.0    67965.0      19.70       39.40  6.694552e+05  4.619241e+09
# 3     21580.0    21580.0       8.30       16.60  8.955700e+04  4.656964e+08
# 4    291631.5   291631.5      20.61       61.83  2.003508e+06  8.504893e+10
# ..        ...        ...        ...         ...           ...           ...
# 296  394260.8   394260.8      34.80      104.40  4.573425e+06  1.554416e+11
# 297  354000.0   354000.0      11.80       23.60  2.088600e+06  1.253160e+11
# 298  967274.0   967274.0      22.00       44.00  1.064001e+07  9.356190e+11
# 299  112500.0   112500.0      37.50      112.50  1.406250e+06  1.265625e+10
# 300   32237.6    32237.6      11.80       23.60  1.902018e+05  1.039263e+09
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: " ,metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.7150178791180121
# Mean Squared Error:  1.1740529241164304
# Root Mean Squared Error:  1.0835372278405715
# R2 Score:  0.9535531064795385

# %%
k_fold = KFold(n_splits = 5) 
results = (cross_val_score(model, x, y.ravel(), cv = k_fold, n_jobs = 1))
print(results)
print(np.mean(results))
# Out:
# [  0.94570144   0.49528202 -18.54760844   0.90648652   0.89236777]
# -3.06155413907448

# %%
df3.shape
# Out:
# (301, 19)

# %%
301/6
# Out:
# 50.166666666666664

# %%
df3
# Out:
#      pres_Kms  pres_Kms2  pres_Fuel  pres_Fuel2     pres2_Kms    pres2_Kms2  \
# 0    150930.0   150930.0      11.18       22.36  8.436987e+05  2.277986e+10
# 1    410220.0   410220.0      28.62       85.86  3.913499e+06  1.682804e+11
# 2     67965.0    67965.0      19.70       39.40  6.694552e+05  4.619241e+09
# 3     21580.0    21580.0       8.30       16.60  8.955700e+04  4.656964e+08
# 4    291631.5   291631.5      20.61       61.83  2.003508e+06  8.504893e+10
# ..        ...        ...        ...         ...           ...           ...
# 296  394260.8   394260.8      34.80      104.40  4.573425e+06  1.554416e+11
# 297  354000.0   354000.0      11.80       23.60  2.088600e+06  1.253160e+11
# 298  967274.0   967274.0      22.00       44.00  1.064001e+07  9.356190e+11
# 299  112500.0   112500.0      37.50      112.50  1.406250e+06  1.265625e+10
# 300   32237.6    32237.6      11.80       23.60  1.902018e+05  1.039263e+09
#
# ...

# %%
df3 = x[x.index < 100] 
df4 = x[x.index > 151]  
x_new = pd.concat([df3, df4])
x_new.reset_index(drop=True, inplace=True)
x_new
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 244          11.60       33988          3            2             2      0
# 245           5.90       60000          2            2             2      0
# 246          11.00       87934          2            2             2      0
# 247          12.50        9000          3            2             2      0
# 248           5.90        5464          2            2             2      0
#
# ...

# %%
df5 = x_new.drop(['Present_Price_2'], axis=1)
df5
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 244          11.60       33988          3            2             2      0
# 245           5.90       60000          2            2             2      0
# 246          11.00       87934          2            2             2      0
# 247          12.50        9000          3            2             2      0
# 248           5.90        5464          2            2             2      0
#
# ...

# %%
y = data["Selling_Price"]  
y1 = y[y.index < 100]  
y2 = y[y.index > 151]  
y_new = pd.concat([y1, y2])
y_new = y_new.reset_index(drop=True)
y_new.shape
# Out:
# (249,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y_new, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: " ,metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.6929443090677954
# Mean Squared Error:  0.9987573870063552
# Root Mean Squared Error:  0.9993785003722839
# R2 Score:  0.9728272517506081

# %% [markdown]
# ## Normalize

# %%
print(x_new[0:5])
x_new["Target"] = y_new
DataFrame = x_new
DataFrame
scaler = preprocessing.StandardScaler().fit(DataFrame)
Norm = scaler.transform(DataFrame.astype(float))
print(Norm[0:5])
# Out:
#    Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0           5.59       27000          2            2             2      0
# 1           9.54       43000          3            2             2      0
# 2           9.85        6900          2            2             2      0
# 3           4.15        5200          2            2             2      0
# 4           6.87       42450          3            2             2      0
#
#    Age  Present_Price_2  Kms_Driven2  Present_Price2  Fuel_Type2  Owner2  \
# 0    5          31.2481    729000000         31.2481           4       0
# 1    6          91.0116   1849000000         91.0116           9       0
# 2    2          97.0225     47610000         97.0225           4       0
# 3    8          17.2225     27040000         17.2225           4       0
# 4    5          47.1969   1802002500         47.1969           9       0
#
#    pres_Kms  pres_Kms2  pres_Fuel  pres_Fuel2    pres2_Kms    pres2_Kms2  \
# ...

# %%
x_norm = DataFrame.drop(["Target"], axis = 1)
y_norm = DataFrame["Target"].values.reshape(-1 , 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_norm, y_norm, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Mean Absolute Error: " ,metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: " ,metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: " ,np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: " ,metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error:  0.6929443090677954
# Mean Squared Error:  0.9987573870063552
# Root Mean Squared Error:  0.9993785003722839
# R2 Score:  0.9728272517506081

# %%
x_test
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 248          5.900        5464          2            2             2      0
# 168          4.430       38488          2            2             2      0
# 76          14.680       72000          2            2             2      0
# 150          5.700       28200          2            2             2      0
# 145          0.510       33000          2            3             2      0
# 73           5.710       43000          2            2             2      0
# 45          12.040       15000          2            2             3      0
# 159         14.790       43535          3            2             2      0
# 218         10.000       69341          2            2             2      0
# 213          8.700       21200          2            2             2      0
# 96          25.390       29000          3            2             3      0
# ...

# %% [markdown]
# #### We put "y_pred" and "y_test" at the fisrt of all columns

# %%
x_test.insert(0, "y_test", y_test)
x_test.insert(0, "y_pred", y_pred)
x_test
# Out:
#         y_pred  y_test  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 248   4.992336    5.30          5.900        5464          2            2
# 168   3.941589    3.50          4.430       38488          2            2
# 76    5.392902    5.50         14.680       72000          2            2
# 150   4.223068    4.40          5.700       28200          2            2
# 145  -0.530110    0.16          0.510       33000          2            3
# 73    2.856412    2.65          5.710       43000          2            2
# 45    9.318783    7.50         12.040       15000          2            2
# 159  10.356049   11.75         14.790       43535          3            2
# 218   3.875929    4.10         10.000       69341          2            2
# 213   6.949170    6.50          8.700       21200          2            2
# 96   20.465820   20.75         25.390       29000          3            2
# 201   6.657056    7.20          9.900       48000          3            2
# ...

# %%
df6= x_test.drop(['Present_Price_2'], axis=1)
df6
# Out:
#         y_pred  y_test  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 248   4.992336    5.30          5.900        5464          2            2
# 168   3.941589    3.50          4.430       38488          2            2
# 76    5.392902    5.50         14.680       72000          2            2
# 150   4.223068    4.40          5.700       28200          2            2
# 145  -0.530110    0.16          0.510       33000          2            3
# 73    2.856412    2.65          5.710       43000          2            2
# 45    9.318783    7.50         12.040       15000          2            2
# 159  10.356049   11.75         14.790       43535          3            2
# 218   3.875929    4.10         10.000       69341          2            2
# 213   6.949170    6.50          8.700       21200          2            2
# 96   20.465820   20.75         25.390       29000          3            2
# 201   6.657056    7.20          9.900       48000          3            2
# ...

# %%
new_df = x_test.sort_values(by = "Present_Price")

# %%
a = new_df.Present_Price
b = new_df.y_test
c = new_df.Present_Price
d = new_df.y_pred

# %%
plt.figure(figsize = (20, 10))
plt.scatter(a, b, color = "blue", label = "real")
plt.scatter(c, d , color = "Orange", label = "Prediction")
plt.legend(fontsize = 60) 
plt.show()

# %%
plt.figure(figsize = (20, 10))
plt.scatter(a, b, color = "blue", label = "real")
plt.plot(c, d , color = "Orange", label = "Prediction")
plt.legend(fontsize = 60)
plt.show()

# %%
df5["Target"] = y_new
y_new
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 244     9.50
# 245     4.00
# 246     3.35
# 247    11.50
# 248     5.30
# Name: Selling_Price, Length: 249, dtype: float64

# %%
df5
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 244          11.60       33988          3            2             2      0
# 245           5.90       60000          2            2             2      0
# 246          11.00       87934          2            2             2      0
# 247          12.50        9000          3            2             2      0
# 248           5.90        5464          2            2             2      0
#
# ...

# %%
print(df5.columns.tolist())
# Out:
# ['Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'Age', 'Kms_Driven2', 'Present_Price2', 'Fuel_Type2', 'Owner2', 'pres_Kms', 'pres_Kms2', 'pres_Fuel', 'pres_Fuel2', 'pres2_Kms', 'pres2_Kms2', 'pres2_Fuel', 'pres2_Fuel2', 'Target']

# %%
Present_price = 11.23
KMS_driven = 42000
Fuel_type = 2      # Petrol
Seller_type = 2    # Dealer
Transmission = 2   # Manual
Owner = 1
Age = 10

# محاسبات از قبل
pp2 = Present_price ** 2
ft2 = Fuel_type ** 2
kms2 = KMS_driven ** 2
owner2 = Owner ** 2

# ساخت دیتافریم با ستون‌های دقیق و منطبق
Model_Input = pd.DataFrame([{
    'Present_Price': Present_price,
    'Kms_Driven': KMS_driven,
    'Fuel_Type': Fuel_type,
    'Seller_Type': Seller_type,
    'Transmission': Transmission,
    'Owner': Owner,
    'Age': Age,
    'Kms_Driven2': kms2,
    'Present_Price2': pp2,
    'Fuel_Type2': ft2,
    'Owner2': owner2,
    'pres_Kms': Present_price * KMS_driven,
    'pres_Kms2': Present_price * kms2,
    'pres_Fuel': Present_price * Fuel_type,
    'pres_Fuel2': Present_price * ft2,
    'pres2_Kms': pp2 * KMS_driven,
    'pres2_Kms2': pp2 * kms2,
    'pres2_Fuel': pp2 * Fuel_type,
    'pres2_Fuel2': pp2 * ft2,
    'Target': 10
}])

# مرتب‌سازی ستون‌ها طبق df5
Model_Input = Model_Input[df5.columns]

#
df5 = df5.reset_index(drop=True)

# حالا Model_Input را به ابتدای df5 اضافه کنید
df5 = pd.concat([df5, Model_Input], ignore_index=True)

# %%
Model_Input
# Out:
#    Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0          11.23       42000          2            2             2      1
#
#    Age  Kms_Driven2  Present_Price2  Fuel_Type2  Owner2  pres_Kms  \
# 0   10   1764000000        126.1129           4       1  471660.0
#
#       pres_Kms2  pres_Fuel  pres_Fuel2  pres2_Kms    pres2_Kms2  pres2_Fuel  \
# 0  1.980972e+10      22.46       44.92  5296741.8  2.224632e+11    252.2258
#
#    pres2_Fuel2  Target
# 0     504.4516      10

# %%
df5
# Out:
#      Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  \
# 0             5.59       27000          2            2             2      0
# 1             9.54       43000          3            2             2      0
# 2             9.85        6900          2            2             2      0
# 3             4.15        5200          2            2             2      0
# 4             6.87       42450          3            2             2      0
# ..             ...         ...        ...          ...           ...    ...
# 245           5.90       60000          2            2             2      0
# 246          11.00       87934          2            2             2      0
# 247          12.50        9000          3            2             2      0
# 248           5.90        5464          2            2             2      0
# 249          11.23       42000          2            2             2      1
#
# ...

# %%
x = df5.drop(["Target"],axis = 1) [:249]
y = df5[["Target"]] [:249]
x_finall = df5.drop(["Target"], axis = 1) [248:249]

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_finall)
y_pred
# Out:
# array([[4.97554723]])

# %% [markdown]
#  <div style = 'border : 10px solid none; background-color:#f2f2f2; padding:10px;font-size:20'>
#
# ### **Price of new Car must be between 4 and 6 iand now we have 4.97554723 that show we have good prediction**
# </div>
